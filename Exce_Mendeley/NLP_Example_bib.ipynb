# %% [markdown]
# Working Directory:
#
# /home/frankie_joe/Desktop/NLP/Exce_Mendeley/data/
#
# Working Folder:
# Exce_Mendeley
#
# Data files:
# JCF201911.bib  test.bib
#
# ## 1. Obtaining Data
#  1.1. Export Librery from Reference Manager as Bibtext. Annotate the total number of papers or entries that were exported.
#  1.2. Explore .bib file using Sublime text editor to see which fields were exported. For example: Key, Author, Title, ISSN, etc.
#  1.3. Save the file within the working folder, inside a subfolder named data. In this example, the file is: JCF201911.bib
#
#  Home/Desktop/NLP/Exec_Mendeley/data
#
#  ## 2. Scraping bib files
#
#  We are going to use a python library "biblib" to parse bibtext files.
#
#  2.1. Go to the Github repository of biblib
#  https://github.com/aclements/biblib
#
#  2.2. clone repository:
#  git clone https://github.com/aclements/biblib
#
#  2.3. Test library and our own data for errors
#  PYTHONPATH=$PWD ./examples/bibparse /home/frankie_joe/Desktop/NLP/Exce_Mendeley/data/JCF201911.bib
#
#  When an error is shown, open the data file and with the line number given in the error message find the corresponding entry and fixed. For example, repeated keys (Same author and year) without subindices. Fix manually and save.
#
#  2.4. Run the same command again. That is, spare the .bib file to make sure there are no more errors.
#
# ## 3. Create local copy of the example code
#
#  3.1. From Github/bliblib/examples folder copy the bibparse file into our working folder and rename it to: bibparse.py.
#
#  3.2. Open bibparse.py in text editor. Add an if in the main code so that it parse also the abstract. For this,  copy one of the existing if loops and replace the field, for example, 'title' for 'abstract'
#
# if 'abstract' in ent:
#         print('  {}'.format(ent['abstract']))
#
# ## 4. Modify the Bibparse code to only print the abstract
#
# 4.1. Duplicate the file bibparse.py.
# 4.2. name the copy as bibparseabs.py and open it. Then comment (with ctrl /) all lines of def code except the print abstract. This is because we only want the abstracts. Save the code
#  Now remove:
#  tabs \t,
#  new line \n
#  c return \r
#  special characters in Latex format. That is within curly brackets
#  print: key, #characters in abstract, abstract
#
#  Save
#
# 4.3. Make a trial of the new modified code using the test.bib file
# ~/Github/nlp_test/Exce_Mendeley$ python3 bibparseabs.py data/test.bib
#
# ## 5. Export to csv
#
# To test the structure of the data, export to csv in Linux console:
#
# ~/Github/nlp_test/Exce_Mendeley$ python3 bibparseabs.py data/test.bib > abstract.csv
#
# Once finished open the file (using the explorer) and verify the format. If okey, then run with the working bib file.
